# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('DESPACHO TERMO/GERACAO_TERMICA_DESPACHO_2021.csv', sep=';', parse_dates=['din_instante'], index_col='din_instante')

# %%
curva_carga_series = pd.read_parquet('CURVA DE CARGA/curva de carga.parquet').loc[lambda x: x.index.year==2021].sum(axis=1)

# %%
curva_carga_series.loc[lambda x: x.index.month==10].resample('MS').apply(np.trapz)
# Out:
# din_instante
# 2021-10-01    4.975991e+07
# Freq: MS, dtype: float64

# %%
#49 GWh

# %%
49/4
# Out:
# 12.25

# %%
fig, ax = plt.subplots()
df[['val_verifgeracao']].groupby('din_instante').sum().loc[lambda x: x.index.month == 10].plot(ax=ax)
#curva_carga_series.loc[lambda x: x.index.month == 10].plot(ax=ax)
# Out:
# <Axes: xlabel='din_instante'>
